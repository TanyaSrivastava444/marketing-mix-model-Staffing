# %% [markdown]
# <a href="https://colab.research.google.com/github/TanyaSrivastava444/marketing-mix-model-Staffing/blob/main/Notebooks/Modelling_transformation_Saturation_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import itertools

# %%
df = pd.read_pickle('/content/df_csv.pkl')

# %%
df.head()
# Out:
#             job_board_spend  linkedin_spend  events_spend  youtube_ads_spend  \
# week
# 2021-01-03        -0.524041       -1.891748     -1.433125          -1.400482
# 2021-01-10        -0.751895       -0.725998     -0.598354          -0.168823
# 2021-01-17        -0.188687       -1.325883     -3.238207          -1.529308
# 2021-01-24         0.421053       -0.218631     -1.249438           1.122995
# 2021-01-31        -0.442846       -0.994995     -0.503811           0.694020
#
#             google_ads_spend  client_outreach_spend  unemployment_rate  \
# week
# 2021-01-03         -1.917682               0.731560           2.072289
# 2021-01-10         -0.335504               0.291253           2.072289
# 2021-01-17         -0.998541              -0.652469           2.072289
# 2021-01-24         -0.064334              -1.182664           2.072289
# 2021-01-31         -0.819811               1.653343           2.072289
#
#             job_openings  payrolls  placements
# week
# 2021-01-03     -2.736924 -1.917194   57.604871
# 2021-01-10     -2.736924 -1.917194   81.520929
# 2021-01-17     -2.736924 -1.917194   90.073056
# 2021-01-24     -2.736924 -1.917194  101.153439
# 2021-01-31     -2.736924 -1.917194  105.179272

# %%
y = df["placements"].values

# %%
# normalize the target
y = (y - y.mean()) / y.std()

# %%
channels = [
"job_board_spend",
"linkedin_spend",
"events_spend",
"youtube_ads_spend",
"google_ads_spend",
"client_outreach_spend"
]

# %%
macro_vars = [
"unemployment_rate",
"job_openings",
"payrolls"
]

# %% [markdown]
# # Decision on Decay
#
# So estimation of decay can be done by grid search , or refer to MMM standards but since the decay rate for some channels are being computed very high then we need to take a step back and use conservative half life decay values to avoid over contributon by a channel and to make the interpretation easier by the stakeholders. So we will use : Half-life = time required for marketing impact to decay by 50%. i.e. decay = 0.4 Use 0.40 across the board. It's the empirical median across digital channels in services industries.It won't catastrophically overstate carryover, and it gives the data room to pull the decay up or down when you move to Phase 2.
#
# Business teams understand time duration better than decay coefficients.

# %% [markdown]
# # Adstock Transformation
#
# carryover effect = Adstockt​=Spendt​+λAdstockt−1​ where lambda = 0.4 decay

# %%
def adstock(x, decay=0.4):
    result = np.zeros(len(x))
    result[0] = x[0]

    for t in range(1, len(x)):
        result[t] = x[t] + decay * result[t-1]

    return result

# %%
for ch in channels:
    df[ch + "_adstock"] = adstock(df[ch], decay=0.5)
# Out:
# /tmp/ipykernel_318/3174554621.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[0] = x[0]
# /tmp/ipykernel_318/3174554621.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[t] = x[t] + decay * result[t-1]
# /tmp/ipykernel_318/3174554621.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[0] = x[0]
# /tmp/ipykernel_318/3174554621.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[t] = x[t] + decay * result[t-1]
# /tmp/ipykernel_318/3174554621.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[0] = x[0]
# /tmp/ipykernel_318/3174554621.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[t] = x[t] + decay * result[t-1]
# /tmp/ipykernel_318/3174554621.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[0] = x[0]
# /tmp/ipykernel_318/3174554621.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[t] = x[t] + decay * result[t-1]
# /tmp/ipykernel_318/3174554621.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[0] = x[0]
# /tmp/ipykernel_318/3174554621.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[t] = x[t] + decay * result[t-1]
# /tmp/ipykernel_318/3174554621.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[0] = x[0]
# /tmp/ipykernel_318/3174554621.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[t] = x[t] + decay * result[t-1]

# %% [markdown]
# Seasonality Modeling (Fourier Terms)
#
# sin(2πkt/T)
#
# ; cos(2πkt/T)

# %%
import numpy as np

def fourier_series(df, period, order):
    t = np.arange(len(df))

    for i in range(1, order+1):
        df[f'sin_{i}'] = np.sin(2 * np.pi * i * t / period)
        df[f'cos_{i}'] = np.cos(2 * np.pi * i * t / period)

    return df

df = fourier_series(df, period=52, order=2)

# %%
# Multicollieniearity

import pandas as pd

# select only numeric columns
corr = df.corr()

print(corr)
# Out:
#                                job_board_spend  linkedin_spend  events_spend  \
# job_board_spend                       1.000000        0.620301      0.497453
# linkedin_spend                        0.620301        1.000000      0.409382
# events_spend                          0.497453        0.409382      1.000000
# youtube_ads_spend                     0.432291        0.482755      0.303821
# google_ads_spend                      0.609194        0.582731      0.492822
# client_outreach_spend                 0.563361        0.386718      0.341107
# unemployment_rate                    -0.305800       -0.325802     -0.295179
# job_openings                         -0.134484       -0.032931      0.068033
# payrolls                              0.402540        0.407125      0.348859
# placements                            0.801116        0.749788      0.611199
# job_board_spend_adstock               0.949736        0.706808      0.549062
# linkedin_spend_adstock                0.744080        0.924762      0.521877
# events_spend_adstock                  0.662937        0.581026      0.901186
# youtube_ads_spend_adstock             0.605844        0.626640      0.429217
# google_ads_spend_adstock              0.742280        0.688257      0.562397
# client_outreach_spend_adstock         0.748854        0.565432      0.441299
# sin_1                                 0.720606        0.621123      0.503682
# cos_1                                 0.014138       -0.115208      0.046000
# sin_2                                -0.016094       -0.078144     -0.069822
# cos_2                                -0.051232        0.006398     -0.094530
#
#                                youtube_ads_spend  google_ads_spend  \
# job_board_spend                         0.432291          0.609194
# linkedin_spend                          0.482755          0.582731
# events_spend                            0.303821          0.492822
# youtube_ads_spend                       1.000000          0.432405
# google_ads_spend                        0.432405          1.000000
# client_outreach_spend                   0.393868          0.484495
# unemployment_rate                      -0.167948         -0.376900
# job_openings                           -0.128582          0.045250
# payrolls                                0.261663          0.454190
# placements                              0.555000          0.721057
# job_board_spend_adstock                 0.507468          0.678051
# linkedin_spend_adstock                  0.515605          0.656210
# events_spend_adstock                    0.384706          0.620788
# youtube_ads_spend_adstock               0.890945          0.537919
# google_ads_spend_adstock                0.513059          0.923816
# client_outreach_spend_adstock           0.495413          0.592032
# sin_1                                   0.463571          0.579209
# cos_1                                  -0.108512         -0.009478
# sin_2                                   0.026292         -0.057531
# cos_2                                   0.022968         -0.070508
#
#                                client_outreach_spend  unemployment_rate  \
# job_board_spend                             0.563361          -0.305800
# linkedin_spend                              0.386718          -0.325802
# events_spend                                0.341107          -0.295179
# youtube_ads_spend                           0.393868          -0.167948
# google_ads_spend                            0.484495          -0.376900
# client_outreach_spend                       1.000000          -0.207844
# unemployment_rate                          -0.207844           1.000000
# job_openings                               -0.153272          -0.568832
# payrolls                                    0.293828          -0.947828
# placements                                  0.600576          -0.184373
# job_board_spend_adstock                     0.624183          -0.322814
# linkedin_spend_adstock                      0.550066          -0.369415
# events_spend_adstock                        0.480740          -0.369319
# youtube_ads_spend_adstock                   0.533767          -0.215569
# google_ads_spend_adstock                    0.588729          -0.431069
# client_outreach_spend_adstock               0.904466          -0.250557
# sin_1                                       0.559008           0.150475
# cos_1                                       0.018306          -0.025312
# sin_2                                       0.064773           0.130596
# cos_2                                      -0.099122           0.033892
#
#                                job_openings  payrolls  placements  \
# job_board_spend                   -0.134484  0.402540    0.801116
# linkedin_spend                    -0.032931  0.407125    0.749788
# events_spend                       0.068033  0.348859    0.611199
# youtube_ads_spend                 -0.128582  0.261663    0.555000
# google_ads_spend                   0.045250  0.454190    0.721057
# client_outreach_spend             -0.153272  0.293828    0.600576
# unemployment_rate                 -0.568832 -0.947828   -0.184373
# job_openings                       1.000000  0.356091   -0.075087
# payrolls                           0.356091  1.000000    0.269013
# placements                        -0.075087  0.269013    1.000000
# job_board_spend_adstock           -0.168088  0.439591    0.871807
# linkedin_spend_adstock            -0.059975  0.475840    0.846159
# events_spend_adstock               0.075644  0.443054    0.756420
# youtube_ads_spend_adstock         -0.161522  0.344196    0.711528
# google_ads_spend_adstock           0.027273  0.533556    0.831609
# client_outreach_spend_adstock     -0.209784  0.364090    0.764418
# sin_1                             -0.279860 -0.068657    0.902032
# cos_1                             -0.150078 -0.034724   -0.063748
# sin_2                             -0.131613 -0.140677   -0.017893
# cos_2                             -0.027371 -0.021983   -0.113613
#
#                                job_board_spend_adstock  \
# job_board_spend                               0.949736
# linkedin_spend                                0.706808
# events_spend                                  0.549062
# youtube_ads_spend                             0.507468
# google_ads_spend                              0.678051
# client_outreach_spend                         0.624183
# unemployment_rate                            -0.322814
# job_openings                                 -0.168088
# payrolls                                      0.439591
# placements                                    0.871807
# job_board_spend_adstock                       1.000000
# linkedin_spend_adstock                        0.843835
# events_spend_adstock                          0.730075
# youtube_ads_spend_adstock                     0.694502
# google_ads_spend_adstock                      0.824911
# client_outreach_spend_adstock                 0.824295
# sin_1                                         0.795822
# cos_1                                        -0.069418
# sin_2                                        -0.030786
# cos_2                                        -0.056875
#
#                                linkedin_spend_adstock  events_spend_adstock  \
# job_board_spend                              0.744080              0.662937
# linkedin_spend                               0.924762              0.581026
# events_spend                                 0.521877              0.901186
# youtube_ads_spend                            0.515605              0.384706
# google_ads_spend                             0.656210              0.620788
# client_outreach_spend                        0.550066              0.480740
# unemployment_rate                           -0.369415             -0.369319
# job_openings                                -0.059975              0.075644
# payrolls                                     0.475840              0.443054
# placements                                   0.846159              0.756420
# job_board_spend_adstock                      0.843835              0.730075
# linkedin_spend_adstock                       1.000000              0.705366
# events_spend_adstock                         0.705366              1.000000
# youtube_ads_spend_adstock                    0.706918              0.542629
# google_ads_spend_adstock                     0.797010              0.729359
# client_outreach_spend_adstock                0.725799              0.605180
# sin_1                                        0.723025              0.655734
# cos_1                                       -0.209431             -0.007182
# sin_2                                       -0.088572             -0.113065
# cos_2                                        0.014556             -0.103817
#
#                                youtube_ads_spend_adstock  \
# job_board_spend                                 0.605844
# linkedin_spend                                  0.626640
# events_spend                                    0.429217
# youtube_ads_spend                               0.890945
# google_ads_spend                                0.537919
# client_outreach_spend                           0.533767
# unemployment_rate                              -0.215569
# job_openings                                   -0.161522
# payrolls                                        0.344196
# placements                                      0.711528
# job_board_spend_adstock                         0.694502
# linkedin_spend_adstock                          0.706918
# events_spend_adstock                            0.542629
# youtube_ads_spend_adstock                       1.000000
# google_ads_spend_adstock                        0.661762
# client_outreach_spend_adstock                   0.678525
# sin_1                                           0.612304
# cos_1                                          -0.205950
# sin_2                                           0.037128
# cos_2                                           0.007948
#
#                                google_ads_spend_adstock  \
# job_board_spend                                0.742280
# linkedin_spend                                 0.688257
# events_spend                                   0.562397
# youtube_ads_spend                              0.513059
# google_ads_spend                               0.923816
# client_outreach_spend                          0.588729
# unemployment_rate                             -0.431069
# job_openings                                   0.027273
# payrolls                                       0.533556
# placements                                     0.831609
# job_board_spend_adstock                        0.824911
# linkedin_spend_adstock                         0.797010
# events_spend_adstock                           0.729359
# youtube_ads_spend_adstock                      0.661762
# google_ads_spend_adstock                       1.000000
# client_outreach_spend_adstock                  0.730192
# sin_1                                          0.688935
# cos_1                                         -0.080001
# sin_2                                         -0.085263
# cos_2                                         -0.075201
#
#                                client_outreach_spend_adstock         sin_1  \
# job_board_spend                                     0.748854  7.206062e-01
# linkedin_spend                                      0.565432  6.211227e-01
# events_spend                                        0.441299  5.036824e-01
# youtube_ads_spend                                   0.495413  4.635713e-01
# google_ads_spend                                    0.592032  5.792094e-01
# client_outreach_spend                               0.904466  5.590079e-01
# unemployment_rate                                  -0.250557  1.504752e-01
# job_openings                                       -0.209784 -2.798605e-01
# payrolls                                            0.364090 -6.865732e-02
# placements                                          0.764418  9.020319e-01
# job_board_spend_adstock                             0.824295  7.958218e-01
# linkedin_spend_adstock                              0.725799  7.230253e-01
# events_spend_adstock                                0.605180  6.557336e-01
# youtube_ads_spend_adstock                           0.678525  6.123036e-01
# google_ads_spend_adstock                            0.730192  6.889354e-01
# client_outreach_spend_adstock                       1.000000  7.139869e-01
# sin_1                                               0.713987  1.000000e+00
# cos_1                                              -0.049408 -1.988992e-03
# sin_2                                               0.047458 -1.787046e-16
# cos_2                                              -0.146390 -8.660553e-02
#
#                                   cos_1         sin_2         cos_2
# job_board_spend                0.014138 -1.609443e-02 -5.123178e-02
# linkedin_spend                -0.115208 -7.814398e-02  6.398335e-03
# events_spend                   0.046000 -6.982223e-02 -9.453047e-02
# youtube_ads_spend             -0.108512  2.629199e-02  2.296823e-02
# google_ads_spend              -0.009478 -5.753124e-02 -7.050801e-02
# client_outreach_spend          0.018306  6.477261e-02 -9.912209e-02
# unemployment_rate             -0.025312  1.305958e-01  3.389228e-02
# job_openings                  -0.150078 -1.316126e-01 -2.737058e-02
# payrolls                      -0.034724 -1.406772e-01 -2.198287e-02
# placements                    -0.063748 -1.789316e-02 -1.136135e-01
# job_board_spend_adstock       -0.069418 -3.078619e-02 -5.687495e-02
# linkedin_spend_adstock        -0.209431 -8.857167e-02  1.455638e-02
# events_spend_adstock          -0.007182 -1.130651e-01 -1.038168e-01
# youtube_ads_spend_adstock     -0.205950  3.712767e-02  7.947816e-03
# google_ads_spend_adstock      -0.080001 -8.526350e-02 -7.520051e-02
# client_outreach_spend_adstock -0.049408  4.745841e-02 -1.463902e-01
# sin_1                         -0.001989 -1.787046e-16 -8.660553e-02
# cos_1                          1.000000  1.691546e-01  1.538553e-02
# sin_2                          0.169155  1.000000e+00  2.135044e-16
# cos_2                          0.015386  2.135044e-16  1.000000e+00

# %%
# Baseline regression to check data quality as data is synthetic

X = df[channels]
y = df["placements"]

model = LinearRegression().fit(X,y)

print("R2:",model.score(X,y))
# Out:
# R2: 0.8313251789165493

# %%
df.shape
# Out:
# (130, 20)

# %% [markdown]
# # Bayesian Regression (PyMC)

# %%
print(X.mean(axis=0))
print(X.std(axis=0))
# Out:
# job_board_spend          7.925284e-16
# linkedin_spend           1.612385e-15
# events_spend             1.038486e-15
# youtube_ads_spend        3.006142e-16
# google_ads_spend        -2.650871e-15
# client_outreach_spend   -1.311771e-15
# dtype: float64
# job_board_spend          1.003868
# linkedin_spend           1.003868
# events_spend             1.003868
# youtube_ads_spend        1.003868
# google_ads_spend         1.003868
# client_outreach_spend    1.003868
# dtype: float64

# %%
features = (
    [c+"_adstock_sat" for c in channels] +
    macro_vars +
    ["sin_1","cos_1","sin_2","cos_2"]
)

X = df[channels].values
y = df["placements"].values

# %%
from sklearn.preprocessing import StandardScaler
import pymc as pm
import numpy as np

features = (
    [c+"_adstock_sat" for c in channels] +
    macro_vars +
    ["sin_1","cos_1","sin_2","cos_2"]
)

X = df[channels].values
y = df["placements"].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

y_scaled = (y - y.mean()) / y.std()

with pm.Model() as mmm_model:

    intercept = pm.Normal("intercept", 0, 1)

    betas = pm.HalfNormal("betas", sigma=0.3, shape=X_scaled.shape[1])

    sigma = pm.HalfNormal("sigma", 1)

    mu = intercept + pm.math.dot(X_scaled, betas)

    placements = pm.Normal("placements", mu=mu, sigma=sigma, observed=y_scaled)

    trace = pm.sample(2000, tune=3000, target_accept=0.99,chains=4,
    cores=4)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Check the real diagnostics (more important than divergences). R-hat < 1.01. ; ESS > 400
import arviz as az
az.summary(trace)
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# betas[0]   0.311  0.057   0.204    0.418      0.001    0.001    5760.0
# betas[1]   0.278  0.051   0.183    0.375      0.001    0.001    7073.0
# betas[2]   0.181  0.044   0.100    0.263      0.001    0.001    6523.0
# betas[3]   0.106  0.044   0.025    0.190      0.001    0.001    3745.0
# betas[4]   0.168  0.052   0.072    0.267      0.001    0.001    5170.0
# betas[5]   0.131  0.046   0.043    0.216      0.001    0.001    4569.0
# intercept -0.000  0.037  -0.068    0.070      0.000    0.000    8889.0
# sigma      0.426  0.028   0.375    0.478      0.000    0.000    6640.0
#
#            ess_tail  r_hat
# betas[0]     3922.0    1.0
# betas[1]     4925.0    1.0
# betas[2]     4487.0    1.0
# betas[3]     2119.0    1.0
# betas[4]     2460.0    1.0
# betas[5]     1768.0    1.0
# intercept    5471.0    1.0
# sigma        4865.0    1.0

# %%
# Visual Check
az.plot_trace(trace)
# Out:
# array([[<Axes: title={'center': 'betas'}>,
#         <Axes: title={'center': 'betas'}>],
#        [<Axes: title={'center': 'intercept'}>,
#         <Axes: title={'center': 'intercept'}>],
#        [<Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'sigma'}>]], dtype=object)

# %%
## Channel Contribution Estimation

beta_means = trace.posterior['betas'].mean(dim=("chain","draw")).values

contribution = X * beta_means

channel_contribution = pd.DataFrame(
contribution,
columns=channels,
index=df.index
)

# %%
beta_means
# Out:
# array([0.31127306, 0.2784997 , 0.18104109, 0.10587047, 0.16759406,
#        0.13126242])

# %%
# Model Evaluation

from sklearn.metrics import r2_score

pred = X.dot(beta_means)

r2 = r2_score(y, pred)

print("R2:", r2)

# %%
wmape = np.sum(np.abs(y - pred)) / np.sum(y)

print("WMAPE:", wmape)
